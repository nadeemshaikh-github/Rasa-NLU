# %% [markdown]
# # Chatbot using Rasa NLU

# %% [markdown]
# ![Screenshot%202020-12-28%20113420.jpg](attachment:Screenshot%202020-12-28%20113420.jpg)

# %% [markdown]
# ____

# %% [markdown]
# # Rasa Chatbot

# %% [markdown]
# ![Screenshot%202020-12-28%20190817.jpg](attachment:Screenshot%202020-12-28%20190817.jpg)
